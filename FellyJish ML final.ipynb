# %%
import tensorflow as tf
import datetime
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

# %%
def load_data(data_directory):
    images = []
    labels = []
    classes = []
    label_encoder = LabelEncoder()

    for class_name in os.listdir(data_directory):
        class_path = os.path.join(data_directory, class_name)
        classes.append(class_name)

        for filename in os.listdir(class_path):
            filepath = os.path.join(class_path, filename)
            img = cv2.imread(filepath)
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert to RGB
                img = cv2.resize(img, (224, 224))
                img = img / 255.0
                images.append(img)
                labels.append(class_name)

    images = np.array(images)
    labels = label_encoder.fit_transform(labels) 

    return images, labels, classes

# Update the path to your dataset
data_directory = 'JellyFish'
images, labels, classes = load_data(data_directory)

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=[classes[label] for label in labels])  
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
classes = np.unique(classes)

# %%
#define the convnet
model = Sequential()
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(16, (3, 3), padding='same', input_shape=(224, 224, 3)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
# FLATTERN => DENSE => RELU => DROPOUT
model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dense(6, activation='softmax'))

model.summary()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
datagen = ImageDataGenerator(
    rotation_range=30,         # Randomly rotate images by 20 degrees
    #brightness_range=[0., 0.5],  # Adjust brightness between 10% and 200%
    width_shift_range=0.1,     # Randomly shift images horizontally by 20% of the width
    height_shift_range=0.1,    # Randomly shift images vertically by 20% of the height
    shear_range=0.1,           # Shear intensity
    zoom_range=0.3,            # Randomly zoom into images
    horizontal_flip=True,      # Randomly flip images horizontally
    vertical_flip=True,        # Randomly flip images vertically
)
datagen1 = ImageDataGenerator()

train_generator = datagen.flow(X_train, y_train, batch_size=20)
val_generator = datagen1.flow(X_test, y_test, batch_size=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  activation (Activation)     (None, 224, 224, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      4640
#
#  activation_1 (Activation)   (None, 224, 224, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  dropout (Dropout)           (None, 112, 112, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18496
#
#  activation_2 (Activation)   (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  dense (Dense)               (None, 128)               25690240
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 25,718,150
# Trainable params: 25,718,150
# Non-trainable params: 0
# _________________________________________________________________

# %%
index = np.random.randint(0, len(X_train))

# Select the original image
original_image = (X_train[index]*255).astype(np.uint8)
original_image = original_image.astype(np.uint8)

# Reshape the selected image to (1, height, width, channels) to make it a batch of size 1
original_image = np.expand_dims(original_image, axis=0)

# Create an iterator for the batch (with only one sample)
iterator = datagen.flow(original_image, batch_size=1)

# Generate augmented images
augmented_images = (iterator.next()).astype(np.uint8)

# Display the original and augmented images
plt.figure(figsize=(8, 4))

# Original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(original_image[0])
plt.axis('off')

# Augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
plt.imshow(augmented_images[0] ,vmax = 1., vmin = 0)
plt.axis('off')

plt.show()

# %%
history = model.fit(train_generator, epochs=150, validation_data=val_generator)
# Out:
# Epoch 1/150
# 36/36 [==============================] - 9s 131ms/step - loss: 2.6465 - accuracy: 0.2542 - val_loss: 1.6761 - val_accuracy: 0.3167
# Epoch 2/150
# 36/36 [==============================] - 4s 123ms/step - loss: 1.5857 - accuracy: 0.3444 - val_loss: 1.5711 - val_accuracy: 0.3444
# Epoch 3/150
# 36/36 [==============================] - 4s 122ms/step - loss: 1.4430 - accuracy: 0.3917 - val_loss: 1.4862 - val_accuracy: 0.4167
# Epoch 4/150
# 36/36 [==============================] - 5s 142ms/step - loss: 1.2871 - accuracy: 0.4833 - val_loss: 1.3471 - val_accuracy: 0.4167
# Epoch 5/150
# 36/36 [==============================] - 5s 123ms/step - loss: 1.3004 - accuracy: 0.4750 - val_loss: 1.3400 - val_accuracy: 0.4889
# Epoch 6/150
# 36/36 [==============================] - 5s 126ms/step - loss: 1.2459 - accuracy: 0.4958 - val_loss: 1.3041 - val_accuracy: 0.4667
# Epoch 7/150
# 36/36 [==============================] - 5s 123ms/step - loss: 1.1898 - accuracy: 0.5153 - val_loss: 1.2778 - val_accuracy: 0.4778
# Epoch 8/150
# 36/36 [==============================] - 5s 124ms/step - loss: 1.1827 - accuracy: 0.5444 - val_loss: 1.4807 - val_accuracy: 0.4333
# Epoch 9/150
# 36/36 [==============================] - 5s 124ms/step - loss: 1.1782 - accuracy: 0.5431 - val_loss: 1.2575 - val_accuracy: 0.4889
# Epoch 10/150
# 36/36 [==============================] - 5s 124ms/step - loss: 1.0921 - accuracy: 0.5778 - val_loss: 1.2374 - val_accuracy: 0.4833
# Epoch 11/150
# 36/36 [==============================] - 5s 124ms/step - loss: 1.0603 - accuracy: 0.5847 - val_loss: 1.1998 - val_accuracy: 0.5222
# Epoch 12/150
# 36/36 [==============================] - 5s 126ms/step - loss: 1.0507 - accuracy: 0.5764 - val_loss: 1.1836 - val_accuracy: 0.5167
# Epoch 13/150
# 36/36 [==============================] - 5s 124ms/step - loss: 1.0186 - accuracy: 0.5750 - val_loss: 1.1897 - val_accuracy: 0.4833
# Epoch 14/150
# 36/36 [==============================] - 5s 125ms/step - loss: 0.9822 - accuracy: 0.6167 - val_loss: 1.0765 - val_accuracy: 0.5944
# Epoch 15/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.9559 - accuracy: 0.6236 - val_loss: 1.1078 - val_accuracy: 0.5444
# Epoch 16/150
# 36/36 [==============================] - 5s 127ms/step - loss: 0.9432 - accuracy: 0.6333 - val_loss: 1.0864 - val_accuracy: 0.5889
# Epoch 17/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.9258 - accuracy: 0.6181 - val_loss: 1.0894 - val_accuracy: 0.5722
# Epoch 18/150
# 36/36 [==============================] - 5s 125ms/step - loss: 0.9261 - accuracy: 0.6236 - val_loss: 1.0796 - val_accuracy: 0.5222
# Epoch 19/150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.8973 - accuracy: 0.6486 - val_loss: 1.0863 - val_accuracy: 0.5722
# Epoch 20/150
# 36/36 [==============================] - 5s 125ms/step - loss: 0.8214 - accuracy: 0.6611 - val_loss: 0.9130 - val_accuracy: 0.6389
# Epoch 21/150
# 36/36 [==============================] - 5s 125ms/step - loss: 0
150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.2095 - accuracy: 0.9278 - val_loss: 0.5695 - val_accuracy: 0.8444
# Epoch 136/150
# 36/36 [==============================] - 5s 127ms/step - loss: 0.1781 - accuracy: 0.9292 - val_loss: 0.5608 - val_accuracy: 0.8278
# Epoch 137/150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.1992 - accuracy: 0.9361 - val_loss: 0.4738 - val_accuracy: 0.9111
# Epoch 138/150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.1178 - accuracy: 0.9625 - val_loss: 0.3709 - val_accuracy: 0.9111
# Epoch 139/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.1702 - accuracy: 0.9486 - val_loss: 0.3927 - val_accuracy: 0.9111
# Epoch 140/150
# 36/36 [==============================] - 5s 125ms/step - loss: 0.2088 - accuracy: 0.9306 - val_loss: 0.5118 - val_accuracy: 0.8667
# Epoch 141/150
# 36/36 [==============================] - 5s 127ms/step - loss: 0.1921 - accuracy: 0.9319 - val_loss: 0.3777 - val_accuracy: 0.8833
# Epoch 142/150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.1379 - accuracy: 0.9569 - val_loss: 0.4604 - val_accuracy: 0.8667
# Epoch 143/150
# 36/36 [==============================] - 5s 133ms/step - loss: 0.0715 - accuracy: 0.9833 - val_loss: 0.3532 - val_accuracy: 0.8944
# Epoch 144/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.1090 - accuracy: 0.9597 - val_loss: 0.4523 - val_accuracy: 0.8556
# Epoch 145/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.1077 - accuracy: 0.9694 - val_loss: 0.4441 - val_accuracy: 0.8889
# Epoch 146/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.1185 - accuracy: 0.9611 - val_loss: 0.4136 - val_accuracy: 0.8889
# Epoch 147/150
# 36/36 [==============================] - 5s 129ms/step - loss: 0.2184 - accuracy: 0.9250 - val_loss: 0.5303 - val_accuracy: 0.8444
# Epoch 148/150
# 36/36 [==============================] - 5s 126ms/step - loss: 0.3199 - accuracy: 0.9153 - val_loss: 0.5475 - val_accuracy: 0.8278
# Epoch 149/150
# 36/36 [==============================] - 5s 124ms/step - loss: 0.1619 - accuracy: 0.9444 - val_loss: 0.3953 - val_accuracy: 0.8944
# Epoch 150/150
# 36/36 [==============================] - 5s 128ms/step - loss: 0.1266 - accuracy: 0.9611 - val_loss: 0.3829 - val_accuracy: 0.9056

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Find the epoch with the highest validation accuracy
best_epoch = val_accuracy.index(max(val_accuracy)) + 1  # Add 1 because epochs are 1-indexed

print(f"Best Accuracy: {accuracy[best_epoch-1]:.4f} at Epoch {best_epoch}")
print(f"Best Validation Accuracy: {val_accuracy[best_epoch-1]:.4f} at Epoch {best_epoch}")
# Out:
# Best Accuracy: 0.9500 at Epoch 111
# Best Validation Accuracy: 0.9167 at Epoch 111

# %%
y_pred_probs = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_true = y_test

conf_matrix = confusion_matrix(y_true, y_pred_labels)

# Calculate class weights to account for imbalanced classes (optional)
weights = class_weight.compute_sample_weight('balanced', y_true)

# Normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Get class names from your data
classes = ["Class1", "Class2", "Class3", "Class4", "Class5", "Class6"]  # Replace with your actual class names

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, annot=True, fmt=".2f", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 6/6 [==============================] - 0s 53ms/step

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
